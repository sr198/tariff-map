# %%
import pandas as pd
import world_trade_data as wits
pd.set_option('display.max_columns', 6)

# %%
wits.get_countries()
# Out:
#                                     name notes countrycode  ...  ispartner  \
# iso3Code                                                    ...
# AFG                          Afghanistan               004  ...      False
# ALB                              Albania               008  ...      False
# DZA                              Algeria               012  ...      False
# ASM                       American Samoa               016  ...      False
# AND                              Andorra               020  ...      False
# ...                                  ...   ...         ...  ...        ...
# YEM                                Yemen               887  ...      False
# YDR                     Yemen Democratic               720  ...      False
# YUG       Yugoslavia,FR(Serbia/Montenegr               890  ...      False
# ZMB                               Zambia               894  ...      False
# ZWE                             Zimbabwe               716  ...      False
#
# ...

# %%
wits.get_products()
# Out:
#                 isgroup nomenclaturecode             grouptype  \
# productcode
# 999999              N/A              N/A                   N/A
# 01-05_Animal        Yes               H0                Sector
# 06-15_Vegetable     Yes               H0                Sector
# 16-24_FoodProd      Yes               H0                Sector
# 25-26_Minerals      Yes               H0                Sector
# 27-27_Fuels         Yes               H0                Sector
# 28-38_Chemicals     Yes               H0                Sector
# 39-40_PlastiRub     Yes               H0                Sector
# 41-43_HidesSkin     Yes               H0                Sector
# 44-49_Wood          Yes               H0                Sector
# 50-63_TextCloth     Yes               H0                Sector
# 64-67_Footwear      Yes               H0                Sector
# 68-71_StoneGlas     Yes               H0                Sector
# 72-83_Metals        Yes               H0                Sector
# ...

# %%
wits.get_indicators()
# Out:
#                     ispartnerequired SDMX_partnervalue isproductrequired  ...  \
# indicatorcode                                                             ...
# CNTRY-GRWTH                      yes                                 yes  ...
# HH-MKT-CNCNTRTN-NDX               no               999                no  ...
# MPRT-PRDCT-SHR                   yes                                 yes  ...
# MPRT-PRTNR-SHR                   yes                                  no  ...
# MPRT-SHR-TTL-PRDCT               yes                                 yes  ...
# MPRT-TRD-VL                      yes                                 yes  ...
# NDX-XPRT-MKT-PNRTTN               no               999                no  ...
# NMBR-MPRT-HS6-PRDCT              yes                                  no  ...
# NMBR-MPRT-PRTNR                   no               999                no  ...
# NMBR-PRDCT-MPRTD                  no               999                no  ...
# ...

# %%
wits.get_indicator('MPRT-TRD-VL', reporter='USA', partner='CHN', year=2022)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 wits.get_indicator('MPRT-TRD-VL', reporter='USA', partner='CHN', year=2022, name_or_id='name')
#
# File d:\workdir\projects\tariff-map\backend\.venv\Lib\site-packages\world_trade_data\data.py:60, in get_indicator(indicator, reporter, partner, product, year, datasource, name_or_id)
#      52 def get_indicator(indicator,
#      53                   reporter,
#      54                   partner='wld',
#    (...)     57                   datasource=world_trade_data.defaults.DEFAULT_DATASOURCE,
#      58                   name_or_id='name'):
#      59     """Get the values for the desired indicator"""
# ---> 60     return _get_data(reporter, partner, product, year,
#      61                      indicator=indicator, datasource=datasource, name_or_id=name_or_id)
#
# ...
